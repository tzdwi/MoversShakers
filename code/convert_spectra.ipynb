# %% [markdown]
# # Now we need to use the Gaia spectral coefficients to output SDSS photometry. Let's start with the blue sample with $u-g\leq0.6$

# %%
from gaiaxpy import PhotometricSystem

PhotometricSystem.get_available_systems()
# Out:
# 'DECam, Els_Custom_W09_S2, Euclid_VIS, Gaia_2, Gaia_DR3_Vega, Halpha_Custom_AB, H_Custom, Hipparcos_Tycho, HST_ACSWFC, HST_HUGS_Std, HST_WFC3UVIS, HST_WFPC2, IPHAS, JKC, JKC_Std, JPAS, JPLUS, JWST_NIRCAM, LSST, PanSTARRS1, PanSTARRS1_Std, Pristine, SDSS, SDSS_Std, Sky_Mapper, Stromgren, Stromgren_Std, WFIRST'

# %%
from gaiaxpy import generate, PhotometricSystem
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import warnings

#Thx StackOverflow user Boris Verkhovskiy
def chunker(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

query = '../data/GaiaQueries/DR3_SDSS_spectra_g_lt_16_ug_lt_0p6-result.csv'
query_df = pd.read_csv(query)
sids = list(query_df.source_id.values)
done = pd.Index(np.array([]))
data = []

# %%
phot_system = PhotometricSystem.SDSS

for j in tqdm(chunker(sids, 5000), total=len(sids)//5000):
    j_s = pd.Index(np.array(j))
    if np.all(j_s.isin(done)):
        continue
    generated_data = generate(j, phot_system, error_correction=True, save_file=False)
    data.append(generated_data)
    done = done.append(j_s)
# Out:
#   0%|          | 0/852 [00:00<?, ?it/s]
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.67s/syst]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/5y/xylgmkx93wg65h8btmx50vn80000gn/T/ipykernel_37045/2797712814.py in <module>
#       7     generated_data = generate(j, phot_system, error_correction=True, save_file=False)
#       8     data.append(generated_data)
# ----> 9     done = done.append(j_s, ignore_index=True)
#
# TypeError: append() got an unexpected keyword argument 'ignore_index'

# %%
out_df = pd.concat(data)
out_df.to_csv('../data/OutputFiles/synthetic_SDSS_ug_le_0p6.csv', index=False)

# %%
query = '../data/GaiaQueries/DR3_SDSS_spectra_g_lt_16-result.csv'
query_df = pd.read_csv(query)
sids = list(query_df.source_id.values)
done = pd.Index(np.array([]))
data = []

# %%
for j in tqdm(chunker(sids, 5000), total=len(sids)//5000):
    j_s = pd.Index(np.array(j))
    if np.all(j_s.isin(done)):
        continue
    try:
        generated_data = generate(j, phot_system, error_correction=True, save_file=False)
    except:
        print('messed up')
        continue
    data.append(generated_data)
    done = done.append(j_s)
# Out:
#   0%|          | 0/852 [00:00<?, ?it/s]
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.65s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.62s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.88s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.95s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.88s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.38s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.27s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.69s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.53s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.26s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.02s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.50s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.60s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.94s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.24s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.50s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.43s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.91s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.73s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.43s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.83s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.50s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.60s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.47s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.58s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.54s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.47s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.53s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.54s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.55s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.68s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.62s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.65s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.60s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.60s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.65s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.51s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.49s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.85s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.55s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.59s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.66s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.68s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.59s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.60s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.64s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.50s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.46s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.44s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.64s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# ...
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.70s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.64s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.69s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.02s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.65s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.72s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.50s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.53s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.43s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.45s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.51s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.66s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.74s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.64s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.65s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.56s/syst]
#
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.96syst/s]

# %%
out_df = pd.concat(data)
out_df.to_csv('../data/OutputFiles/synthetic_SDSS_ug_gt_0p6.csv', index=False)

# %% [markdown]
# # Clean up, I think we missed one...

# %%
from glob import glob

queries = glob('../data/GaiaQueries/DR3_SDSS_spectra_g_lt_16*')
qs = []
for q in queries:
    qs.append(pd.read_csv(q))
qs = pd.concat(qs)

sids = list(qs.source_id.values)

phots = glob('../data/OutputFiles/synthetic_SDSS_ug_*')
ph = []
for p in phots:
    ph.append(pd.read_csv(p))
ph = pd.concat(ph)

done = pd.Index(ph.source_id.values)
print(len(sids),len(done))
# Out:
# 4598275 4603275

# %%
phot_system = PhotometricSystem.SDSS
data = []

for j in tqdm(chunker(sids, 5000), total=len(sids)//5000):
    j_s = pd.Index(np.array(j))
    if np.all(j_s.isin(done)):
        continue
    try:
        generated_data = generate(j, phot_system, error_correction=True, save_file=False)
    except:
        print('messed up')
        continue
    data.append(generated_data)
    done = done.append(j_s)
    
out_df = pd.concat(data)
out_df.to_csv('../data/OutputFiles/synthetic_SDSS_leftovers.csv', index=False)
# Out:
#   0%|          | 0/919 [00:00<?, ?it/s]
# Generating photometry:   0%|                                                                                                                                        | 0/2 [00:00<?, ?syst/s]
#
# Correcting systems:   0%|                                                                                                                                           | 0/1 [00:00<?, ?syst/s]
# Correcting systems: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:09<00:00,  9.79s/syst]
